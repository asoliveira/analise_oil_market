# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
db = pd.read_csv("./opec/data_05_11_16.csv", index_col=0, parse_dates=True)
db.head()
# Out:
#             Value
# Date
# 2003-01-02  30.05
# 2003-01-03  30.83
# 2003-01-06  30.71
# 2003-01-07  29.72
# 2003-01-08  28.86

# %%
db.plot()

# %%
db.plot(kind="hist")

# %%
returns = (db - db.shift(1))/db
returns.plot()

# %%
returns.plot(kind="hist")

# %%
returns.plot?
